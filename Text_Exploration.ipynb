# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd 
import numpy as np
from preprocessing.cleaning_utils import *
from functools import partial
import torch 

from datasets import load_dataset
from datasets import Value, ClassLabel, Features, DatasetDict
import transformers
from transformers import AutoTokenizer, AutoModel, AutoModelForMaskedLM, AutoModelForSequenceClassification
from transformers import DataCollatorWithPadding
from transformers import logging
from transformers import TrainingArguments, Trainer

logging.set_verbosity_warning()

# %%
# !python -m torch.utils.collect_env

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device
# Out:
# device(type='cuda')

# %%
mimic_dir = "/home/vs428/project/MIMIC/files/mimiciii/1.4/"
n2c2_dir = "/home/vs428/project/n2c2/2022/N2C2-AP-Reasoning/"
n2c2_data_dir =  "/home/vs428/project/n2c2/2022/Data/"

# %%
samples = pd.read_csv(n2c2_dir + "n2c2_sample.csv")
samples_raw = pd.read_csv(n2c2_dir + "n2c2_sample_raw.csv")

# %%
# classes = ['Not Relevant', 'Neither', 'Indirect', 'Direct']
# features = Features({
#     'ROW ID':Value("int64"),
#     'HADM ID':Value("int64"),
#     'Assessment':Value("string"),
#     'PlanSubsection':Value("string"),
#     "Relation":Value("string")
# }) 
# dataset = load_dataset("csv", data_files=n2c2_dir + "n2c2_sample_raw.csv", 
#                        features=features)
# dataset = dataset.class_encode_column("Relation")
# dataset = dataset.rename_column("Relation", "label")

# %%
classes = ['Not Relevant', 'Neither', 'Indirect', 'Direct']
features = Features({
    'ROW ID':Value("int64"),
    'HADM ID':Value("int64"),
    'Assessment':Value("string"),
    'Plan Subsection':Value("string"),
    "Relation":Value("string")
}) 

dataset = load_dataset("csv", data_files={
                            "train":n2c2_data_dir + "train.csv",
                            "valid":n2c2_data_dir + "dev.csv",
                        },

                       features=features)
# dataset = dataset.class_encode_column("Relation")
dataset = dataset.rename_column("Relation", "label")
# Out:
# Using custom data configuration default-b1948d86214b7517
# Reusing dataset csv (/home/vs428/.cache/huggingface/datasets/csv/default-b1948d86214b7517/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
dataset['train'][23]
# Out:
# {'ROW ID': 711150,
#  'HADM ID': 183333,
#  'Assessment': '75 yo M with h/o cardiomyopahy (EF 15%), atrial fibrillation, pulmonary\n   embolism (on coumadin), adrenal insufficiency, and s/p several recent\n   admissions following episode of Klebsilella pneumonia complicated by\n   respiratory failure and septic shock. Presents to hospital with\n   syncope, hypoxia, hypotension and altered mental status.',
#  'Plan Subsection': '# Adrenal insufficiency:\n   Patient on 10 mg hydrocortisone at home.\n   - Increase to 50 mg hydrocortisone given stress of acute illness (day 2\n   today)',
#  'label': 'Indirect'}

# %% [markdown]
# # Check some assumptions about the data

# %% [markdown]
# ## Check if any "direct" relations have no overlap

# %%
import scispacy
import spacy
from scispacy.abbreviation import AbbreviationDetector

# %%
nlp = spacy.load("en_core_sci_lg")
nlp.add_pipe("abbreviation_detector")

# %%
non_overlap_direct_rels = []
for data in dataset['train']:
    if data['label'] == "Direct":
        assessment_tokens = set(w.orth for w in nlp(data['Assessment']))
        plan_tokens = set(w.orth for w in nlp(data['Plan Subsection']))
        if len(assessment_tokens.intersection(plan_tokens)) < 1:
            print(data)
            non_overlap_direct_rels.append(data)
# Out:
# /gpfs/ysm/project/rtaylor/vs428/conda_envs/myenv/lib/python3.10/site-packages/scispacy/abbreviation.py:230: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   global_matches = self.global_matcher(doc)
# {'ROW ID': 476539, 'HADM ID': 111846, 'Assessment': 'This is a 55M with COPD/CO2 retainer, VTE,  bilateral chronic\n   lymphedema and multiple ulcers who was admited for LE cellulitis/sepsis\n   and who underwent BKA three days ago is transferred to MICU for medical\n   management', 'Plan Subsection': 'Hypotension: resolved', 'label': 'Direct'}
# {'ROW ID': 358146, 'HADM ID': 106860, 'Assessment': '79F Russian speaking s/p CABG, dCHF s/p dual pacemaker, DMII, AF,\n   CRI that presents with decreased PO and hypotension likely [**2-19**] to\n   decresed PO in setting of UTI and potential PNA.', 'Plan Subsection': 'HYPOTENSION (NOT SHOCK)\n COUGH', 'label': 'Direct'}
# {'ROW ID': 634432, 'HADM ID': 199781, 'Assessment': '57 y.o. man with DM, HTN, and paranoid schizophrenia, presents from\n   inpatient Psych facility altered mental status', 'Plan Subsection': 'Respiratory alkalosis: Resolved on intubation', 'label': 'Direct'}
# {'ROW ID': 685471, 'HADM ID': 106691, 'Assessment': '48yo F intoxicated s/p fall down stairs with\n   severe facial trauma, elective OSH intubation for airway protection.', 'Plan Subsection': 'Pain: fentanyl', 'label': 'Direct'}
# {'ROW ID': 429862, 'HADM ID': 110437, 'Assessment': '53 year old female with hx of alcoholism presents with hepatic and\n   renal failure.  Transfered to ICU with new oxygen requirement.\n   .', 'Plan Subsection': 'HEPATIC FAILURE, FULMINANT\n RENAL FAILURE, ACUTE (ACUTE RENAL FAILURE, ARF)\n RESPIRATORY FAILURE, ACUTE (NOT ARDS/[**Doctor Last Name 11**])', 'label': 'Direct'}
# {'ROW ID': 657674, 'HADM ID': 108863, 'Assessment': '55yo female with resolving ARDS and H. flu bacteremia presents for\n   re-admission to the MICU for increased O2 requirement.\n   .', 'Plan Subsection': 'AROUSAL, ATTENTION, AND COGNITION, IMPAIRED\n MUSCLE PERFORMACE, IMPAIRED\n RESPIRATION / GAS EXCHANGE, IMPAIRED\n KNOWLEDGE, IMPAIRED', 'label': 'Direct'}
# {'ROW ID': 657674, 'HADM ID': 108863, 'Assessment': '55yo female with resolving ARDS and H. flu bacteremia presents for\n   re-admission to the MICU for increased O2 requirement.\n   .', 'Plan Subsection': 'PNEUMONIA, OTHER', 'label': 'Direct'}
# {'ROW ID': 376139, 'HADM ID': 111063, 'Assessment': '66 yo M with obesity hypoventilation, ? COPD, afib, ESRD on HD, PVD\n   with recent TMA ulcer, who presents with confusion, shortness of\n   breath, fever and hypotension.\n   .', 'Plan Subsection': 'SEPSIS WITHOUT ORGAN DYSFUNCTION', 'label': 'Direct'}
# {'ROW ID': 376139, 'HADM ID': 111063, 'Assessment': '66 yo M with obesity hypoventilation, ? COPD, afib, ESRD on HD, PVD\n   with recent TMA ulcer, who presents with confusion, shortness of\n   breath, fever and hypotension.\n   .', 'Plan Subsection': 'ALTERED MENTAL STATUS (NOT DELIRIUM)', 'label': 'Direct'}
# {'ROW ID': 376139, 'HADM ID': 111063, 'Assessment': '66 yo M with obesity hypoventilation, ? COPD, afib, ESRD on HD, PVD\n   with recent TMA ulcer, who presents with confusion, shortness of\n   breath, fever and hypotension.\n   .', 'Plan Subsection': 'HYPOTENSION (NOT SHOCK)', 'label': 'Direct'}
# {'ROW ID': 586068, 'HADM ID': 188769, 'Assessment': 'BACTEREMIA\n ATRIAL FIBRILLATION (AFIB)\n FEVER, UNKNOWN ORIGIN (FUO, HYPERTHERMIA, PYREXIA)', 'Plan Subsection': '# afib: cont coumadin', 'label': 'Direct'}
# {'ROW ID': 527062, 'HADM ID': 103550, 'Assessment': '89 year old right handed man with type 2 diabetes\n   mellitus, peripheral vascular disease, atrial\n   fibrillation on coumadin with a sub therapeutic INR, CAD, HLD\n   presenting with a C2 fracture and acute/subacute right cerebellar\n   infarct', 'Plan Subsection': 'Pain:  Fentanyl', 'label': 'Direct'}

# %%
non_overlap_direct_df = pd.DataFrame(non_overlap_direct_rels)

# %%
for idx, data in non_overlap_direct_df.iterrows():
    prompt_str = 'Assessment: ' + data['Assessment'] + '\nPlan: ' + data['Plan Subsection'] + '\nLabel: ' \
        + str(data['label'])
    print(prompt_str)
    print("\n---------------------------------------------\n")
# Out:
# Assessment: This is a 55M with COPD/CO2 retainer, VTE,  bilateral chronic
#    lymphedema and multiple ulcers who was admited for LE cellulitis/sepsis
#    and who underwent BKA three days ago is transferred to MICU for medical
#    management
# Plan: Hypotension: resolved
# Label: Direct
#
# ---------------------------------------------
#
# Assessment: 79F Russian speaking s/p CABG, dCHF s/p dual pacemaker, DMII, AF,
#    CRI that presents with decreased PO and hypotension likely [**2-19**] to
#    decresed PO in setting of UTI and potential PNA.
# Plan: HYPOTENSION (NOT SHOCK)
#  COUGH
# Label: Direct
#
# ---------------------------------------------
#
# Assessment: 57 y.o. man with DM, HTN, and paranoid schizophrenia, presents from
#    inpatient Psych facility altered mental status
# Plan: Respiratory alkalosis: Resolved on intubation
# Label: Direct
#
# ---------------------------------------------
#
# Assessment: 48yo F intoxicated s/p fall down stairs with
#    severe facial trauma, elective OSH intubation for airway protection.
# Plan: Pain: fentanyl
# Label: Direct
#
# ---------------------------------------------
#
# Assessment: 53 year old female with hx of alcoholism presents with hepatic and
#    renal failure.  Transfered to ICU with new oxygen requirement.
#    .
# Plan: HEPATIC FAILURE, FULMINANT
#  RENAL FAILURE, ACUTE (ACUTE RENAL FAILURE, ARF)
#  RESPIRATORY FAILURE, ACUTE (NOT ARDS/[**Doctor Last Name 11**])
# Label: Direct
#
# ---------------------------------------------
#
# Assessment: 55yo female with resolving ARDS and H. flu bacteremia presents for
#    re-admission to the MICU for increased O2 requirement.
#    .
# Plan: AROUSAL, ATTENTION, AND COGNITION, IMPAIRED
#  MUSCLE PERFORMACE, IMPAIRED
#  RESPIRATION / GAS EXCHANGE, IMPAIRED
#  KNOWLEDGE, IMPAIRED
# Label: Direct
#
# ---------------------------------------------
#
# Assessment: 55yo female with resolving ARDS and H. flu bacteremia presents for
#    re-admission to the MICU for increased O2 requirement.
#    .
# Plan: PNEUMONIA, OTHER
# Label: Direct
#
# ---------------------------------------------
#
# Assessment: 66 yo M with obesity hypoventilation, ? COPD, afib, ESRD on HD, PVD
#    with recent TMA ulcer, who presents with confusion, shortness of
#    breath, fever and hypotension.
#    .
# Plan: SEPSIS WITHOUT ORGAN DYSFUNCTION
# Label: Direct
#
# ---------------------------------------------
#
# Assessment: 66 yo M with obesity hypoventilation, ? COPD, afib, ESRD on HD, PVD
#    with recent TMA ulcer, who presents with confusion, shortness of
#    breath, fever and hypotension.
#    .
# Plan: ALTERED MENTAL STATUS (NOT DELIRIUM)
# Label: Direct
#
# ---------------------------------------------
#
# Assessment: 66 yo M with obesity hypoventilation, ? COPD, afib, ESRD on HD, PVD
#    with recent TMA ulcer, who presents with confusion, shortness of
#    breath, fever and hypotension.
#    .
# Plan: HYPOTENSION (NOT SHOCK)
# Label: Direct
#
# ---------------------------------------------
#
# Assessment: BACTEREMIA
#  ATRIAL FIBRILLATION (AFIB)
#  FEVER, UNKNOWN ORIGIN (FUO, HYPERTHERMIA, PYREXIA)
# Plan: # afib: cont coumadin
# Label: Direct
#
# ---------------------------------------------
#
# Assessment: 89 year old right handed man with type 2 diabetes
#    mellitus, peripheral vascular disease, atrial
#    fibrillation on coumadin with a sub therapeutic INR, CAD, HLD
#    presenting with a C2 fracture and acute/subacute right cerebellar
#    infarct
# Plan: Pain:  Fentanyl
# Label: Direct
#
# ---------------------------------------------

# %% [markdown]
# ## "Indirect" Relations that don't have much overlap

# %%
non_overlap_indirect_rels = []
for data in dataset['train']:
    if data['label'] == "Indirect":
        assessment_tokens = set(w.orth for w in nlp(data['Assessment']))
        plan_tokens = set(w.orth for w in nlp(data['Plan Subsection']))
        if len(assessment_tokens.intersection(plan_tokens)) < 1:
            print(data)
            non_overlap_indirect_rels.append(data)
# Out:
# /gpfs/ysm/project/rtaylor/vs428/conda_envs/myenv/lib/python3.10/site-packages/scispacy/abbreviation.py:230: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   global_matches = self.global_matcher(doc)
# {'ROW ID': 553008, 'HADM ID': 195768, 'Assessment': 'MYOCARDIAL INFARCTION, ACUTE (AMI, STEMI, NSTEMI)\n GASTROINTESTINAL BLEED, LOWER (HEMATOCHEZIA, BRBPR, GI BLEED, GIB)\n TACHYCARDIA, OTHER\n RESPIRATORY FAILURE, ACUTE (NOT ARDS/[**Doctor Last Name 2**])\n   69F w/ h/o afib on coumadin, PUD, COPD, CKD, h/o CVA, HTN,\n   hyperlipidemia transferred from [**Hospital1 709**] by family request after presenting\n   with black stools, developed hypoxemia and tachyarrhythmia with RVR,\n   now with continued respiratory distress complicated by demand ischemia.', 'Plan Subsection': '# Hypercholesterolemia: Continue statin', 'label': 'Indirect'}
# {'ROW ID': 580343, 'HADM ID': 183659, 'Assessment': '53M with HIV/hepC, admitted with nausea, weakness, hypotension', 'Plan Subsection': '# hypoglycemia - likely [**12-30**] septic picture and possibly complicated by\n   ESLD.\n   - D50 as needed.\n   - check FSBS QID.', 'label': 'Indirect'}
# {'ROW ID': 657100, 'HADM ID': 100571, 'Assessment': 'his is a 66 y/o M hx seizures from EEE encephalitis p/w status c/b\n   aspiration PNA, intubated in NICU, and NSTEMI and extubated on [**2-21**].\n   Transferred to floor on [**2-24**] and continues to have some mild\n   respiratory distress, tachypnea.\n   .', 'Plan Subsection': 'H/O ENCEPHALITIS', 'label': 'Indirect'}
# {'ROW ID': 566675, 'HADM ID': 109844, 'Assessment': '79 yof with hx of HTN, Hyperlipidemia, Hypothyroidism, who presented to\n   [**Hospital 839**] Hosp with SOB and chest pressure, found to be in acute CHF,\n   transferred here s/p traumatic intubation c/b tracheal tear and\n   subcutaneous emphysema.  Now transferred to CCU for management of afib\n   with RVR. Febrile overnight with episode of afib/rvr, converted to\n   sinus with amiodarone.', 'Plan Subsection': 'Hyperthyroidism: restart Levothyroxine when POs OK', 'label': 'Indirect'}
# {'ROW ID': 638868, 'HADM ID': 198207, 'Assessment': 'FEVER (HYPERTHERMIA, PYREXIA, NOT FEVER OF UNKNOWN ORIGIN)\n TACHYCARDIA, OTHER\n CANCER (MALIGNANT NEOPLASM), PANCREAS\n SUPRAVENTRICULAR TACHYCARDIA (SVT)\n RENAL FAILURE, ACUTE (ACUTE RENAL FAILURE, ARF)\n LIVER FUNCTION ABNORMALITIES\n ANEMIA, CHRONIC\n HYPERTENSION, BENIGN\n   58 year-old male with history of pancreatic cancer presented [**2117-10-6**]\n   with fever and tachycardia.', 'Plan Subsection': 'HTN: hold lopressor for now', 'label': 'Indirect'}
# {'ROW ID': 398915, 'HADM ID': 149546, 'Assessment': '79 yo female with CAD s/p CABG with only patent LIMA-LAD, COPD, HTN,\n   afib who presents with hematochezia, anemia, and angina', 'Plan Subsection': 'DYSPNEA (SHORTNESS OF BREATH)', 'label': 'Indirect'}
# {'ROW ID': 705139, 'HADM ID': 190704, 'Assessment': '49 yo female with history of hypercholesterolemia admitted for chest\n   pain and EKG changes consistent with inferior STEMI, found to have no\n   obstructing lesions on cath, most consistent with Takotsubos\n   cardiomyopathy', 'Plan Subsection': '# Hypercholesterolemia:  Continue statin', 'label': 'Indirect'}
# {'ROW ID': 657674, 'HADM ID': 108863, 'Assessment': '55yo female with resolving ARDS and H. flu bacteremia presents for\n   re-admission to the MICU for increased O2 requirement.\n   .', 'Plan Subsection': 'ELECTROLYTE & FLUID DISORDER, OTHER', 'label': 'Indirect'}
# {'ROW ID': 534086, 'HADM ID': 111116, 'Assessment': '82 year old man with hx of T3N0 colon ca s/p transverse colectomy in\n   [**2122**] c/b incisional hernia, dementia, DM2, HTN presents with high\n   fever, lethargy, emesis, positive u/a.', 'Plan Subsection': 'DM\n ISS', 'label': 'Indirect'}
# {'ROW ID': 325354, 'HADM ID': 112343, 'Assessment': '87 year old Russian-speaking female with h/o breast cancer, esophageal\n   cancer (requiring esophogeal stent), afib, DMII, s/p EGD with\n   additional stent placement adm with hematemesis/UGIB initially HD\n   stable with decompensation\n   .', 'Plan Subsection': 'DM: sliding scale', 'label': 'Indirect'}
# {'ROW ID': 721481, 'HADM ID': 101199, 'Assessment': '52y F with 2wk HA found to have L SDH with midline\n   shift.', 'Plan Subsection': 'h/o GERD, PUD - cont PPI', 'label': 'Indirect'}
# {'ROW ID': 437644, 'HADM ID': 199705, 'Assessment': 'This 51F with alcoholic cirrhosis presents with hematemesis.', 'Plan Subsection': '# EtoH abuse\n   - monitor per CIWA, ativan prn\n   - MVT/thiamine/folate (banana bag daily\n   - social work/[**First Name8 (NamePattern2) 780**] [**Last Name (NamePattern1) 820**] consult in AM', 'label': 'Indirect'}
# {'ROW ID': 559423, 'HADM ID': 149752, 'Assessment': '79M w/ pmh significant for SIADH, COPD, BPH s/p TURP, ulcerative\n   colitis,  presenting with abdominal pain, diahrrea, leukocytosis, and\n   severe hyponatremia.', 'Plan Subsection': 'Peripheral Neuropathy: Continue neurontin', 'label': 'Indirect'}
# {'ROW ID': 439899, 'HADM ID': 192999, 'Assessment': '89 F w/ PMHx of hypothyroid, prior syncopal episodes of unknown\n   etiology presents w/ syncope and high degree AV block, now s/p\n   temporary pacer placement.', 'Plan Subsection': '#) Hypothyroidism: Continue levothyroxine', 'label': 'Indirect'}
# {'ROW ID': 709485, 'HADM ID': 149619, 'Assessment': '52 year old male with diabetes, hypertension, active smoker presenting\n   with inferior STEMI s/p placement of 3 stents to proximal, mid, and\n   distal RCA admitted to CCU for observation\n   .', 'Plan Subsection': 'Dyslipidemia\n holding statin (see above)', 'label': 'Indirect'}
# {'ROW ID': 639467, 'HADM ID': 110316, 'Assessment': '89 year old woman with hypertension, paroxysmal atrial fibrillation,\n   aortic stenosis, recent pseudomonas bacteremia, presenting with nausea,\n   vomiting, bradycardia, hypotension and respiratory failure, in critical\n   condition. [**2121-10-24**] patient experienced R anterior MCA infarct.\n   .', 'Plan Subsection': 'Hypothyroidism: continue levothyroxine', 'label': 'Indirect'}
# {'ROW ID': 625154, 'HADM ID': 105444, 'Assessment': '73F PMHx of IDDM, seizure disorder and breast cancer presenting with R\n   hip fx s/p fall and admitted to the ICU initially with ARF and troponin\n   leak; now s/p ORIF of R hip with post-op hypoxia.', 'Plan Subsection': 'Seizure Disorder: continue home medications', 'label': 'Indirect'}
# {'ROW ID': 585163, 'HADM ID': 106334, 'Assessment': 'ALTERED MENTAL STATUS (NOT DELIRIUM)\n HYPOXEMIA\n CARDIAC DYSRHYTHMIA OTHER\n FEVER (HYPERTHERMIA, PYREXIA, NOT FEVER OF UNKNOWN ORIGIN)\n IMPAIRED SKIN INTEGRITY\n   This is a 55 year-old man with metastatic melanoma who presents with\n   altered mental status and hemorrhagic brain mets.\n   .', 'Plan Subsection': 'Tachycardia/bradycardia: Pt', 'label': 'Indirect'}
# {'ROW ID': 527062, 'HADM ID': 103550, 'Assessment': '89 year old right handed man with type 2 diabetes\n   mellitus, peripheral vascular disease, atrial\n   fibrillation on coumadin with a sub therapeutic INR, CAD, HLD\n   presenting with a C2 fracture and acute/subacute right cerebellar\n   infarct', 'Plan Subsection': 'Cont. beta blockade for heart rate control due to h/o afib.', 'label': 'Indirect'}
# {'ROW ID': 438035, 'HADM ID': 199238, 'Assessment': 'H/O CVA (STROKE, CEREBRAL INFARCTION), OTHER\n PNEUMONIA, [**Hospital 50**] HOSPITAL ACQUIRED (NON-VAP)\n HYPOTENSION (NOT SHOCK)\n   78F with h/o stroke with R hemiparesis and aphasia presents with\n   hypoxia, volume overload/CHF, and hypotension', 'Plan Subsection': '# ? RIJ/RSC DVT: f/u RUE UE', 'label': 'Indirect'}
# {'ROW ID': 656572, 'HADM ID': 190187, 'Assessment': '87 year old female with a h/o CAD s/p PCI, htn, hyperlipidemia, breast\n   cancer s/p lumpectomy and XRT who presents with altered mental status\n   found to be hyponatremic', 'Plan Subsection': '# Hypercholesterolemia: cont statin', 'label': 'Indirect'}
# {'ROW ID': 361936, 'HADM ID': 191117, 'Assessment': '59M with CAD, CHF, DM, ESRD on HD, who presents with hypotension and\n   sepsis now much improved, off pressors, extubated, mental status\n   appears normal.', 'Plan Subsection': '# HyperKalemia - resolved', 'label': 'Indirect'}

# %%
non_overlap_indirect_df = pd.DataFrame(non_overlap_indirect_rels)

# %%
for idx, data in non_overlap_indirect_df.iterrows():
    prompt_str = 'Assessment: ' + data['Assessment'] + '\nPlan: ' + data['Plan Subsection'] + '\nLabel: ' \
        + str(data['label'])
    print(prompt_str)
    print("\n---------------------------------------------\n")
# Out:
# Assessment: MYOCARDIAL INFARCTION, ACUTE (AMI, STEMI, NSTEMI)
#  GASTROINTESTINAL BLEED, LOWER (HEMATOCHEZIA, BRBPR, GI BLEED, GIB)
#  TACHYCARDIA, OTHER
#  RESPIRATORY FAILURE, ACUTE (NOT ARDS/[**Doctor Last Name 2**])
#    69F w/ h/o afib on coumadin, PUD, COPD, CKD, h/o CVA, HTN,
#    hyperlipidemia transferred from [**Hospital1 709**] by family request after presenting
#    with black stools, developed hypoxemia and tachyarrhythmia with RVR,
#    now with continued respiratory distress complicated by demand ischemia.
# Plan: # Hypercholesterolemia: Continue statin
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 53M with HIV/hepC, admitted with nausea, weakness, hypotension
# Plan: # hypoglycemia - likely [**12-30**] septic picture and possibly complicated by
#    ESLD.
#    - D50 as needed.
#    - check FSBS QID.
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: his is a 66 y/o M hx seizures from EEE encephalitis p/w status c/b
#    aspiration PNA, intubated in NICU, and NSTEMI and extubated on [**2-21**].
#    Transferred to floor on [**2-24**] and continues to have some mild
#    respiratory distress, tachypnea.
#    .
# Plan: H/O ENCEPHALITIS
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 79 yof with hx of HTN, Hyperlipidemia, Hypothyroidism, who presented to
#    [**Hospital 839**] Hosp with SOB and chest pressure, found to be in acute CHF,
#    transferred here s/p traumatic intubation c/b tracheal tear and
#    subcutaneous emphysema.  Now transferred to CCU for management of afib
#    with RVR. Febrile overnight with episode of afib/rvr, converted to
#    sinus with amiodarone.
# Plan: Hyperthyroidism: restart Levothyroxine when POs OK
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: FEVER (HYPERTHERMIA, PYREXIA, NOT FEVER OF UNKNOWN ORIGIN)
#  TACHYCARDIA, OTHER
#  CANCER (MALIGNANT NEOPLASM), PANCREAS
#  SUPRAVENTRICULAR TACHYCARDIA (SVT)
#  RENAL FAILURE, ACUTE (ACUTE RENAL FAILURE, ARF)
#  LIVER FUNCTION ABNORMALITIES
#  ANEMIA, CHRONIC
#  HYPERTENSION, BENIGN
#    58 year-old male with history of pancreatic cancer presented [**2117-10-6**]
#    with fever and tachycardia.
# Plan: HTN: hold lopressor for now
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 79 yo female with CAD s/p CABG with only patent LIMA-LAD, COPD, HTN,
#    afib who presents with hematochezia, anemia, and angina
# Plan: DYSPNEA (SHORTNESS OF BREATH)
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 49 yo female with history of hypercholesterolemia admitted for chest
#    pain and EKG changes consistent with inferior STEMI, found to have no
#    obstructing lesions on cath, most consistent with Takotsubos
#    cardiomyopathy
# Plan: # Hypercholesterolemia:  Continue statin
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 55yo female with resolving ARDS and H. flu bacteremia presents for
#    re-admission to the MICU for increased O2 requirement.
#    .
# Plan: ELECTROLYTE & FLUID DISORDER, OTHER
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 82 year old man with hx of T3N0 colon ca s/p transverse colectomy in
#    [**2122**] c/b incisional hernia, dementia, DM2, HTN presents with high
#    fever, lethargy, emesis, positive u/a.
# Plan: DM
#  ISS
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 87 year old Russian-speaking female with h/o breast cancer, esophageal
#    cancer (requiring esophogeal stent), afib, DMII, s/p EGD with
#    additional stent placement adm with hematemesis/UGIB initially HD
#    stable with decompensation
#    .
# Plan: DM: sliding scale
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 52y F with 2wk HA found to have L SDH with midline
#    shift.
# Plan: h/o GERD, PUD - cont PPI
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: This 51F with alcoholic cirrhosis presents with hematemesis.
# Plan: # EtoH abuse
#    - monitor per CIWA, ativan prn
#    - MVT/thiamine/folate (banana bag daily
#    - social work/[**First Name8 (NamePattern2) 780**] [**Last Name (NamePattern1) 820**] consult in AM
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 79M w/ pmh significant for SIADH, COPD, BPH s/p TURP, ulcerative
#    colitis,  presenting with abdominal pain, diahrrea, leukocytosis, and
#    severe hyponatremia.
# Plan: Peripheral Neuropathy: Continue neurontin
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 89 F w/ PMHx of hypothyroid, prior syncopal episodes of unknown
#    etiology presents w/ syncope and high degree AV block, now s/p
#    temporary pacer placement.
# Plan: #) Hypothyroidism: Continue levothyroxine
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 52 year old male with diabetes, hypertension, active smoker presenting
#    with inferior STEMI s/p placement of 3 stents to proximal, mid, and
#    distal RCA admitted to CCU for observation
#    .
# Plan: Dyslipidemia
#  holding statin (see above)
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 89 year old woman with hypertension, paroxysmal atrial fibrillation,
#    aortic stenosis, recent pseudomonas bacteremia, presenting with nausea,
#    vomiting, bradycardia, hypotension and respiratory failure, in critical
#    condition. [**2121-10-24**] patient experienced R anterior MCA infarct.
#    .
# Plan: Hypothyroidism: continue levothyroxine
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 73F PMHx of IDDM, seizure disorder and breast cancer presenting with R
#    hip fx s/p fall and admitted to the ICU initially with ARF and troponin
#    leak; now s/p ORIF of R hip with post-op hypoxia.
# Plan: Seizure Disorder: continue home medications
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: ALTERED MENTAL STATUS (NOT DELIRIUM)
#  HYPOXEMIA
#  CARDIAC DYSRHYTHMIA OTHER
#  FEVER (HYPERTHERMIA, PYREXIA, NOT FEVER OF UNKNOWN ORIGIN)
#  IMPAIRED SKIN INTEGRITY
#    This is a 55 year-old man with metastatic melanoma who presents with
#    altered mental status and hemorrhagic brain mets.
#    .
# Plan: Tachycardia/bradycardia: Pt
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 89 year old right handed man with type 2 diabetes
#    mellitus, peripheral vascular disease, atrial
#    fibrillation on coumadin with a sub therapeutic INR, CAD, HLD
#    presenting with a C2 fracture and acute/subacute right cerebellar
#    infarct
# Plan: Cont. beta blockade for heart rate control due to h/o afib.
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: H/O CVA (STROKE, CEREBRAL INFARCTION), OTHER
#  PNEUMONIA, [**Hospital 50**] HOSPITAL ACQUIRED (NON-VAP)
#  HYPOTENSION (NOT SHOCK)
#    78F with h/o stroke with R hemiparesis and aphasia presents with
#    hypoxia, volume overload/CHF, and hypotension
# Plan: # ? RIJ/RSC DVT: f/u RUE UE
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 87 year old female with a h/o CAD s/p PCI, htn, hyperlipidemia, breast
#    cancer s/p lumpectomy and XRT who presents with altered mental status
#    found to be hyponatremic
# Plan: # Hypercholesterolemia: cont statin
# Label: Indirect
#
# ---------------------------------------------
#
# Assessment: 59M with CAD, CHF, DM, ESRD on HD, who presents with hypotension and
#    sepsis now much improved, off pressors, extubated, mental status
#    appears normal.
# Plan: # HyperKalemia - resolved
# Label: Indirect
#
# ---------------------------------------------

# %%
mimic_dir = "/home/vs428/project/MIMIC/files/mimiciii/1.4/"
notes = pd.read_csv(mimic_dir + "NOTEEVENTS.csv")
# Out:
# /tmp/ipykernel_4338/2468265868.py:2: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   notes = pd.read_csv(mimic_dir + "NOTEEVENTS.csv")

# %%
# notes[notes['HADM_ID'] == 183659]
print(notes[notes['ROW_ID'] == 580343]['TEXT'].tolist()[0])
# Out:
# Chief Complaint:  weakness, shortness of breath.
#    HPI:
#    53M with h/o ESLD [**12-30**] hepC, HIV (CD4 322), pHTN, presenting to ED this
#    morning with weakness, nausea, and cough.  Per his caregiver [**Name (NI) 1708**], he
#    was in his USOH until 4AM, and had been doing relatively well since his
#    last discharge [**3-29**] at which time dobhoff was replaced [**12-30**] weight loss,
#    tolerating tube feeds poorly, but recently switching to oral feeds only
#    for the past 1.5 weeks.
#    .
#    He had no complaints prior to going to bed, other than his baseline
#    abdominal discomfort, and nausea.  His caregiver found him at 4AM
#    slumped towards the left on the couch, incontient of urine and stool
#    (wears depends at baseline), and disoriented.  EMS was activated, and
#    he was brought to ED.
#    .
#    The patient denies confusion, hemetemesis, melena, or change in his
#    chronic abdominal pain, and has been having daily soft bowel movements
#    on lactulose.
#    .
#    In ED VS=98.1  98/70  103  24  92%RA.  Labs notable for LACTATE 8.0,
#    WBC 25.2, 9%bands, CRE 1.2 (bl 0.9), CE flat, TBIL 5.5 (bl [**3-3**]).  CXR
#    with RLL effusion, and ?infiltrate.  RUQ with moderate abdominal fluid,
#    single large gallstone with gallbladder wall thickening.  His BP
#    dropped to the 85/63, for which he received 500cc with improved BP.  In
#    total he received 5L IV with repeat lactate was 8.4, and 800cc UOP
#    after foley placement.  He had a single FSBS 30s for which he received
#    1AMP D50.  He received CTX/azithro/vanc, and then zosyn.  Plan was for
#    CVL, however pt declined this.  His access is 2 PIVs.  Guaic negative
#    rectal exam.
#    .
#    Of note, he was recently admitted to [**Hospital1 1**] [**Date range (1) 6701**] with clogged
#    dobhoff, ascites, and dyspnea.  PEG was placed for enteric feeding.
#    Paracentesis removed 4L of fluid, with WBC 1100 with 2%PMN.  CTA and
#    RHC found no PE, and worsening pHTN.  1.6L left side thoracentesis was
#    reported as transudative though by LDH, appears exudative given
#    pLDH/sLDH 0.7 (LDH 145, TP 2.7, WBC 100, RBC 20,500, serum LDH 200 (ULN
#    250), serum TP not measured).
#    .
#    Upon arrival to the ICU, pt and caregiver note improved mental status,
#    but worsening tachypnea after having recieved IVF in ED.
#    Patient admitted from: [**Hospital1 1**] ER
#    History obtained from Patient, Family / Friend
#    Allergies:
#    Sulfa (Sulfonamides)
#    Fever/Chills;
#    Last dose of Antibiotics:
#    Infusions:
#    Other ICU medications:
#    Other medications:
#    1. Peptamen 60) ml/hr PO continuousto be administered by post-pyloric
#    Dobhoff tube.
#    2. Abacavir 300 mg PO BID (2 times a day).
#    3. Clotrimazole 10 mg Troche 5 TIMES PER DAY -> NOT TAKING
#    4. Lactulose 30 ML PO DAILY.
#    5. Lamivudine 300 mg PO once a day.
#    6. Lopinavir-Ritonavir 200-50 mg 2 Tablet PO BID (2 times a day).
#    7. Metoclopramide 5 mg PO three times a day -> NOT TAKING
#    8. Omeprazole 20 mg PO DAILY (Daily).
#    9. Oxycodone 5 mg PO Q6H
#    10. Propranolol 20 mg PO BID
#    11. Rifaximin 200 mg PO BID
#    12. Tenofovir Disoproxil Fumarate 300 mg PO DAILY (Daily).
#    13. Cholecalciferol (Vitamin D3) 800 unit PO DAILY (Daily).
#    14. Ferrous Sulfate 325 mg PO DAILY (Daily).
#    15. Latanoprost 0.005 % Drops 1Ophthalmic HS
#    16. compazine prn.
#    17. megace prn.
#    Past medical history:
#    Family history:
#    Social History:
#    - HIV x26yr (CD4 322, VL undetectable [**3-6**])
#    - hepC x10yr cirrhosis, c/b grade [**11-29**] esophageal varices [**2-3**], hepatic
#    hydrothorax s/p thoracentesis [**3-6**], ascites, portal htn, de-listed on
#    [**3-6**] [**12-30**] PAH.
#    - pulmonary htn - RHC in [**3-6**] showed:
#      PA {s/d/m} baseline: 65/26/40  100%O2 67/25/38 inhald NO 65/28/39)
#      WEDGE {a/v/m}        22/23/16         25/25/19           23/24/19
#    - ?LLL lung nodule - incidental finding on CTA [**3-6**], PET-CT without
#    uptake in lung c/w rounded atelectasis, but low-level uptake in benign
#    appearing neck nodules, plan for sildenafil once prior auth complete.
#    - s/p hip replacement in [**2146**] for avascular necrosis
#    - osteopenia
#    NC
#    Occupation: disabled
#    Drugs: former (quit 19y ago)
#    Tobacco: former
#    Alcohol: former
#    Other:
#    Review of systems:
#    Constitutional: Fatigue
#    Ear, Nose, Throat: Dry mouth
#    Nutritional Support: Tube feeds
#    Respiratory: Cough, Dyspnea
#    Gastrointestinal: Abdominal pain
#    Pain: [**11-29**] Minimal
#    Flowsheet Data as of [**2155-5-13**] 02:00 PM
#    Vital Signs
#    Hemodynamic monitoring
#    Fluid Balance
#                                                                   24 hours
#                                                                Since 12 AM
#    Tmax: 36.2
# C (97.2
#    Tcurrent: 36.2
# C (97.2
#    HR: 85 (85 - 93) bpm
#    BP: 96/63(72) {96/63(72) - 118/78(82)} mmHg
#    RR: 27 (20 - 28) insp/min
#    SpO2: 97%
#    Heart rhythm: SR (Sinus Rhythm)
#    Height: 72 Inch
#              Total In:
#              5,838 mL
#    PO:
#              TF:
#    IVF:
#    38 mL
#    Blood products:
#    Total out:
#                                                                       0 mL
#                                                                     330 mL
#    Urine:
#    240 mL
#    NG:
#    Stool:
#    Drains:
#    Balance:
#                                                                       0 mL
#                                                                   5,508 mL
#    Respiratory
#    O2 Delivery Device: Nasal cannula, Venti mask
#    SpO2: 97%
#    Physical Examination
#    General Appearance: Thin, cachectic
#    Eyes / Conjunctiva: PERRL, Pupils dilated, Conjunctiva pale
#    Head, Ears, Nose, Throat: Normocephalic, Poor dentition, NG tube
#    Lymphatic: Cervical WNL
#    Cardiovascular: (Murmur: Systolic)
#    Peripheral Vascular: (Right radial pulse: Present), (Left radial pulse:
#    Present), (Right DP pulse: Present), (Left DP pulse: Present)
#    Respiratory / Chest: (Expansion: Symmetric), (Breath Sounds: No(t)
#    Clear : , Crackles : , Diminished: RLL)
#    Abdominal: Soft, Bowel sounds present, distended, tense.
#    Extremities: Right: Absent, Left: Trace
#    Musculoskeletal: Muscle wasting
#    Skin:  Not assessed
#    Neurologic: Attentive, Follows simple commands, Responds to: Verbal
#    stimuli, Oriented (to): person, place, time, president., Movement:
#    Purposeful, Tone: Not assessed, [**4-1**] deltoid, bicep, tricep, wrist
#    extension, hip flexion, [**Last Name (un) 6702**]/plantarflexion. denies neck pain, full
#    ROM of neck.  negative kernig/burdzinksi.
#    Labs / Radiology
#    65
#         [image002.jpg]
#                                   [**2151-11-29**]
#                           2:33 A6/16/[**2154**]  01:00 PM
#                                   [**2151-12-3**]
#                                    10:20 P
#                                   [**2151-12-4**]
#                                    1:20 P
#                                   [**2151-12-5**]
#                                    11:50 P
#                                   [**2151-12-6**]
#                                    1:20 A
#                                   [**2151-12-7**]
#                                    7:20 P
#                                   1//11/006
#                                    1:23 P
#                                   [**2151-12-30**]
#                                    1:20 P
#                                   [**2151-12-30**]
#                                    11:20 P
#                                   [**2151-12-30**]
#                                    4:20 P
#    Glucose
#                                      65
#    Other labs: PT / PTT / INR:22.6/43.3/2.1
#    Assessment and Plan
#    53M with HIV/hepC, admitted with nausea, weakness, hypotension.
#    .
#    # weakness/atered mental status - no focal neurologic deficits, and no
#    witnessed seizure activity at home.  has some tremor, but no frank
#    asterixis.  most concerning for infection given his distended abdomen,
#    and leukocytosis, with pulmonary and abdominal sources most
#    concerning.  no evidence of meningitis now.
#    - continue lactulose, rifaximin.
#    - seizure precautions.
#    - check ucx, bcx, stool cx with cdiff.
#    - d/w liver service how/when to pursue diagnostic paracentesis -> usn
#    guided paracentesis.
#    - check serum/urine tox screen.
#    - continue vanc/zosyn empirically for presumed abdominal/pulmonary
#    source, and add flagyl.
#    - consider CT A/P to evaluate for abdominal source given lactate of 8,
#    though may be [**12-30**] HIV meds.
#    .
#    # hypoxia - pt presents with cough, though not frankly hypoxic upon
#    arrival to ED, with worsening hypoxia in setting of aggressive fluid
#    repletion.  CXR prior to fluids, at 6am showed chronic bilateral
#    pleural effusions, though R>>L, with ?RLL infiltrate.  his story is
#    concerning for RLL pneumonia, and possibly aspiration given his recent
#    vomitting, but must also consider opportunitistic infections given his
#    HIV (though typically occur with CD4<200) and empyema given his fluid
#    collection.
#    - repeat CXR now.
#    - DFA to r/o flu.
#    - continue vanc/zosyn.
#    - ID consult as above.
#    - discuss utility of tapping RLL effusion, though seems moderate sized,
#    and could try diuretics first (though h/o bumping creatinine in this
#    setting, and recent hypotension), but could r/o empyema also given
#    leukocytosis. (will need FFP prior to [**Female First Name (un) 231**]).
#    - consider CTA of CHEST with CT A/P above to r/o PE and evaluate RLL
#    effusion.
#    .
#    # lactate - no prior lactate's in OMR, and although HIV meds can raise
#    lactate (abacavir, lamivudine -> neutral [**First Name8 (NamePattern2) 24**] [**Doctor Last Name **], tenofovir -> not [**First Name8 (NamePattern2) 24**]
#    [**Doctor Last Name **]), current overall picture is concerning for sepsis based on
#    leukocytosis, and hypotension, with failure to improve lactate after 6L
#    IVF.
#    - trend lactate Q6H.
#    - follow UOP closely.
#    - d/w ID value of holding HIV meds in setting of acute illness with
#    rising lactate.
#    - ID consult re how to manage HIV meds (will hold for now), sepsis.
#    - consider ct abd/pelvis given lack of clear source, to look for
#    evidence of ischemic colitis, abcess.
#    .
#    # ?seizure - unclear history of bowel/bladder incontinence which is new
#    for patient, though he wears depends at baseline.  no focal neurologic
#    deficits presently, but hypoglycemia may have contributed.
#    - seizure precautions.
#    - follow finger sticks closley.
#    - consider CT HEAD.
#    - treat with D5W + 3amps bicarb @ 100cc/hr.
#    .
#    # hypoglycemia - likely [**12-30**] septic picture.
#    - bolus with D5W + 3amps bicarb prior to CT scan.
#    - continue D5W as above.
#    - check FSBS QID.
#    .
#    # leukocytosis - new leukocytosis, with bandemia.  would look for
#    infection as above.  he did have an episode of hypoglycemia in ED,
#    which presumably is [**12-30**] septic physiology, and is without h/o DM to
#    suggest DKA.
#    - check cultures as above.
#    - CT TORSO to evaluate for PNA, and abdominal source.
#    .
#    # ESLD - [**12-30**] hepC, h/o encephalopathy, +varices, no h/o SBP, HRS.  off
#    of transplant list [**12-30**] pHTN. albumin 2.6.  MELD 23.
#    - liver consult.
#    - continue lactulose/rifaximin.
#    - hold propanalol given hypotension.
#    - discuss diuretics with liver team as apparently poor response in the
#    past, will hold off for now given hypotension.
#    .
#    # metabolic acidosis - gap 16, lactate 8.0, with trace ketones in
#    urine, and hypoglycemia in ED.  DKA therefore unlikely.  his picture is
#    more concerning for septic picture, with some possible contribution
#    from starvation ketosis.
#    - trend CHEM7 in PM.
#    - trend lactate.
#    - check ABG/VBG now.
#    - give bicarb as above, for CT torso.
#    .
#    # ARF - baseline cre 0.9, now 1.2, so he is above his baseline.  at
#    elevated risk for volume depletion, AIN (abx at last admission), ATN,
#    and HRS.
#    - check urine lytes now as he has received 5L IVF in ED.
#    - consider albumin.
#    - give bicarb, and mucomyst for CTA.
#    - trend creatinine.
#    .
#    # HIV - CD4 300s, VL undetectable.  concern for elevated lactate [**12-30**]
#    HIV meds.  should also consider opportunistic pathogens.
#    - hold home regimen for now.
#    - ID consult as above.
#    .
#    # pulmonary HTN - not yet on sildenafil as outpatient.
#    .
#    # FEN: continue tube feeds, megace. compazine/zofran prn.
#    # Prophylaxis: pneumoboots, outpatient ppi (switch to lansoprazole).
#    # Access: PIVx2, consider TLC CVL, and a-line if hypotensive.
#    # Code: FULL
#    # Communication: Patient, partner [**First Name8 (NamePattern2) **] [**Last Name (NamePattern1) 6703**] (hcp) [**Telephone/Fax (1) 6704**]
#    # Disposition: pending above
#    .
#    ICU Care
#    Nutrition:
#    Glycemic Control:
#    Lines:
#    18 Gauge - [**2155-5-13**] 11:01 AM
#    20 Gauge - [**2155-5-13**] 11:01 AM
#    Prophylaxis:
#    DVT: SQ UF Heparin
#    Stress ulcer:
#    VAP:
#    Comments:
#    Communication: Patient discussed on interdisciplinary rounds , Family
#    meeting held , ICU consent signed Comments:
#    Code status: Full code
#    Disposition: ICU
